# %%
import pandas as pd

# %%
nice = pd.read_csv("eval_set.csv")
nice
# Out:
#      type_domain     article_id  rev  task_type_id         task_type  \
# 0        Finance   Finance_1022    0             4     Summarization
# 1        Finance   Finance_1032    0             4     Summarization
# 2        Finance   Finance_1037    0             4     Summarization
# 3        Finance   Finance_1062    0             0  Creative writing
# 4        Finance   Finance_1069    0             0     Brainstorming
# ...          ...            ...  ...           ...               ...
# 6282     Medical  Medical_29666    0             4     Summarization
# 6283     Medical  Medical_29714    0             4     Summarization
# 6284     Medical  Medical_29724    0             4     Summarization
# 6285     Medical  Medical_29749    0             2         Closed QA
# 6286     Medical  Medical_31779    0             4     Summarization
#
#                                             Instruction  \
# 0       จงสรุปบทความ QT น่ากังวลกว่า Recession ณ ตรงนี้
# ...

# %%
nice["task_type"].unique()
# Out:
# array(['Summarization', 'Creative writing', 'Brainstorming', 'Closed QA',
#        'Classification', 'Open QA', 'Multiple choice'], dtype=object)
